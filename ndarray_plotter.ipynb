# %%
# %pylab inline
import numpy as np
import jazz
reload(jazz)

subject = np.ones((3,4,3))
plotter = jazz.NDArrayPlotter(subject.shape)
(fig, ax) = plotter.render(subject,elev=30)
(fig, ax) = plotter.render(subject,elev=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['colors']
# `%pylab --no-import-all` prevents importing * from pylab and numpy

# %%
subject = np.ones((5,5,5))
plotter = jazz.NDArrayPlotter(subject.shape, scale=(0.5,0.5,0.5),color="#FF0000",alpha=0.5)
(fig, ax) = plotter.render(subject,elev=30)

# %%
subject = np.ones((1,10,10))
plotter = jazz.NDArrayPlotter(subject.shape)

alphas = plotter.set_alpha(0.5)
colors = plotter.set_color("#00FF00")

i = 1
colors[0,i,i] = "#0000FF"
colors[0,i,i+1] = "#FF0000"
colors[0,i,i-1] = "#FF0000"
colors[0,i+1,i] = "#FF0000"
colors[0,i-1,i] = "#FF0000"

(fig, ax) = plotter.render(subject)
